# %% [markdown]
# https://docs.ragas.io/en/latest/concepts/metrics/index.html
#
# https://medium.com/@mauryaanoop3/implementing-rag-evaluation-with-ragas-and-langchain-a-practical-guide-e1d5ce203c2e
#
# https://github.com/philschmid/evaluate-llms/blob/main/notebooks/01-use-langchain-for-llm-evaluation.ipynb
#
# https://docs.smith.langchain.com/old/cookbook/testing-examples/ragas
