# %% [markdown]
# # Fine Tunnig Notes

# %% [markdown]
# https://www.youtube.com/watch?v=eC6Hd1hFvos  -- FineTunning

# %% [markdown]
# ### Quantization Concept

# %% [markdown]
# Quantization - conversion from higher format to a lower memory format.
#
# In Neural Network, Weights are stored in 32 bit and it is stored as FP 32 that is full precesion or single precesion. F16 is half precesion.
#
# In LLM models like Llama2, model parameters are 70B which includes weights and bais. we cannot finetune with simple GPU and loaded into RAM. We require lot of config to do that.
#
# We will convert from 32 bit to int 8 and then use it. We will be able to inferencing. This is what we call as Quantization. Inferencing means getting faster output. We can use it in CV and NLP models as well where weights are very large.
#
# If we want to use any model in mobile then we would also require Quantization.
#
# We will lose the information and accuracy while quantization since we are converting F32 to Int 8. Calibration comes into the picture.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### calibration or Types of Quantization
#
# 1) Symetric Quantization - It works on batch normalisation.
# 2) Asymetrix Quantization
