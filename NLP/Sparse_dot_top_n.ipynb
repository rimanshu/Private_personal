# %% [markdown]
# # sparse_dot_topn Cosine Similarity
#
# https://towardsdatascience.com/de-duplicate-the-duplicate-records-from-scratch-f6e5ad9e79da
#
# https://github.com/ing-bank/sparse_dot_topn/blob/master/sparse_dot_topn/awesome_cossim_topn.py
#
# https://medium.com/wbaa/https-medium-com-ingwbaa-boosting-selection-of-the-most-similar-entities-in-large-scale-datasets-450b3242e618
#
# https://bergvca.github.io/2017/10/14/super-fast-string-matching.html
#
# https://laptrinhx.com/fast-string-matching-in-python-1391866645/

# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
import sparse_dot_topn.sparse_dot_topn as ct
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv('https://raw.githubusercontent.com/susanli2016/NLP-with-Python/master/data/Seattle_Hotels_Duplicates.csv', encoding="latin-1")
df.head()
# Out:
#                                  name  \
# 0  Hilton Garden Inn Seattle Downtown
# 1              Sheraton Grand Seattle
# 2       Crowne Plaza Seattle Downtown
# 3       Kimpton Hotel Monaco Seattle
# 4                  The Westin Seattle
#
#                                            address
# 0  1821 Boren Avenue, Seattle Washington 98101 USA
# 1   1400 6th Avenue, Seattle, Washington 98101 USA
# 2                  1113 6th Ave, Seattle, WA 98101
# 3                   1101 4th Ave, Seattle, WA98101
# 4   1900 5th Avenue, Seattle, Washington 98101 USA

# %%
df[df.duplicated()]
# Out:
#                      name                                address
# 28      Ace Hotel Seattle        2423 1st Ave, Seattle, WA 98121
# 92  Seattle Inn Northgate  12035 Aurora Ave N, Seattle, WA 98133

# %%
df[df['name']=="Ace Hotel Seattle"]
# Out:
#                  name                          address
# 16  Ace Hotel Seattle  2423 1st Ave, Seattle, WA 98121
# 28  Ace Hotel Seattle  2423 1st Ave, Seattle, WA 98121

# %%
df['name_address']=df['name'] + df['address']
name_address = df['name_address']
vectorizer = TfidfVectorizer("char", ngram_range=(1,4), sublinear_tf=True)
tf_idf_matrix = vectorizer.fit_transform(name_address)

# %%
def awesome_cossim_top(A, B, ntop, lower_bound=0):
  
    A = A.tocsr()
    B = B.tocsr()
    M, _ = A.shape
    _, N = B.shape
    
    print('A.shape', M, _,'B.shape',_, N)
 
    idx_dtype = np.int32
 
    nnz_max = M*ntop
    print("dfdfdfdf.........\n",nnz_max)
 
    indptr = np.zeros(M+1, dtype=idx_dtype)
    indices = np.zeros(nnz_max, dtype=idx_dtype)
    data = np.zeros(nnz_max, dtype=A.dtype)

    #print(data)
    
    ct.sparse_dot_topn(
        M, N, np.asarray(A.indptr, dtype=idx_dtype),
        np.asarray(A.indices, dtype=idx_dtype),
        A.data,
        np.asarray(B.indptr, dtype=idx_dtype),
        np.asarray(B.indices, dtype=idx_dtype),
        B.data,
        ntop,
        lower_bound,
        indptr, indices, data)

    return csr_matrix((data,indices,indptr),shape=(M,N))

matches = awesome_cossim_top(tf_idf_matrix, tf_idf_matrix.transpose(), 5)
print(matches)
# Out:
# A.shape 168 2858 B.shape 2858 168
# dfdfdfdf.........
#  840
#   (0, 0)	0.9999999999999997
#   (0, 9)	0.5824171218360623
#   (0, 1)	0.3135113883850482
#   (0, 4)	0.31182166147590334
#   (0, 6)	0.23730879157386087
#   (1, 1)	0.9999999999999997
#   (1, 6)	0.37350377496055537
#   (1, 4)	0.34081048235170586
#   (1, 0)	0.3135113883850482
#   (1, 12)	0.1378160050853022
#   (2, 2)	0.9999999999999997
#   (2, 12)	0.2483514281936836
#   (2, 55)	0.22749304847306903
#   (2, 147)	0.22472137317266058
#   (2, 25)	0.1762294271026541
#   (3, 3)	0.9999999999999996
#   (3, 11)	0.14172746547004708
#   (3, 33)	0.13191309118835334
#   (3, 163)	0.11319401219045719
#   (3, 107)	0.10020761079690314
#   (4, 4)	0.9999999999999996
#   (4, 1)	0.34081048235170586
#   (4, 0)	0.31182166147590334
#   (4, 6)	0.23956702643172306
#   (4, 12)	0.11151354775913253
#   :	:
#   (163, 163)	0.9999999999999996
#   (163, 33)	0.3476878520347567
#   (163, 11)	0.2775417459288508
#   (163, 107)	0.2716986280293083
#   (163, 164)	0.24838232512963154
#   (164, 164)	1.0
#   (164, 107)	0.385089856273933
#   (164, 33)	0.25653240909114183
#   (164, 153)	0.2517257693868726
#   (164, 163)	0.24838232512963154
#   (165, 165)	1.0
#   (165, 166)	0.6733649833153401
#   (165, 15)	0.244248889644463
#   (165, 30)	0.23821941677007014
#   (165, 37)	0.12792849383210042
#   (166, 166)	1.0000000000000002
#   (166, 165)	0.6733649833153401
#   (166, 15)	0.244248889644463
#   (166, 30)	0.23821941677007014
#   (166, 37)	0.12792849383210042
#   (167, 167)	1.0000000000000002
#   (167, 158)	0.6295237743226807
#   (167, 157)	0.21025994118212776
#   (167, 118)	0.1999630063793544
#   (167, 152)	0.09760065137662674

# %%
def get_matches_df(sparse_matrix, name_vector, top=840):
    non_zeros = sparse_matrix.nonzero()
    
    sparserows = non_zeros[0]
    sparsecols = non_zeros[1]
    
    if top:
        nr_matches = top
    else:
        nr_matches = sparsecols.size
    
    left_side = np.empty([nr_matches], dtype=object)
    right_side = np.empty([nr_matches], dtype=object)
    similairity = np.zeros(nr_matches)
    
    for index in range(0, nr_matches):
        left_side[index] = name_vector[sparserows[index]]
        right_side[index] = name_vector[sparsecols[index]]
        similairity[index] = sparse_matrix.data[index]
    
    return pd.DataFrame({'left_side': left_side,
                          'right_side': right_side,
                           'similarity': similairity})

matches_df = get_matches_df(matches, name_address)

# %%
matches_df[matches_df['similarity'] < 0.99999].sort_values(by=['similarity'], ascending=False).head(30)
# Out:
#                                              left_side  \
# 206  Holiday Inn Express & Suites Seattle-City Cent...
# 256  Holiday Inn Express & Suites Seattle City Cent...
# 826  Pike's Place Lux Suites by Barsala2nd Ave and ...
# 831  Pike's Place Lux Suites by Barsala2rd Ave and ...
# 181  Travelodge Seattle by The Space Needle200 6th ...
# 211  Travelodge Seattle by The Space Needle200 6th ...
# 791  citizenM Seattle South Lake Union hotel201 Wes...
# 836  citizenM Seattle South Lake Union hotel201 Wes...
# 1    Hilton Garden Inn Seattle Downtown1821 Boren A...
# 46   Hilton Garden Inn Seattle Downtown1821 Boren A...
# 781  Hyatt Regency Lake Washington At SeattleS Sout...
# 746  Hyatt Regency Lake Washington At SeattleS Sout...
# 551  Quality Inn & Suites Seattle Center618 John St...
# 586  Quality Inn & Suites Seattle Center618 John St...
# 341  Home2 Suites by Hilton Seattle Airport380 Upla...
# 346  Home2 Suites by Hilton Seattle Airport380 Upla...
# 616  Mediterranean Inn425 Queen Anne Ave N, Seattle...
# 406  MarQueen Hotel600 Queen Anne Ave N, Seattle, W...
# 396  Travelodge by Wyndham Seattle North of Downtow...
# 391  Days Inn by Wyndham Seattle North of Downtown9...
# 636    Hyatt At Olive 91635 8th Ave, Seattle, WA 98101
# 631    Hyatt At Olive 81635 8th Ave, Seattle, WA 98101
# 561  Renaissance Seattle Hotel515 Madison Street, S...
# 546  Renaissance Seattle Hotel515 Madison St, Seatt...
# 441  Comfort Inn & Suites13700 Aurora Avenue North,...
# 401  Comfort Inn & Suites13700 Aurora Ave N, Seattl...
# 671  Watertown Hotel - A Staypineapple Hotel4242 Ro...
# 706  University Inn - A Staypineapple Hotel4140 Roo...
# 451  Roy Street Commons621 12th Avenue East, Seattl...
# 411  Roy Street Commons621 12th Ave E, Seattle, WA ...
#
#                                             right_side  similarity
# 206  Holiday Inn Express & Suites Seattle City Cent...    0.680559
# 256  Holiday Inn Express & Suites Seattle-City Cent...    0.680559
# 826  Pike's Place Lux Suites by Barsala2rd Ave and ...    0.673365
# 831  Pike's Place Lux Suites by Barsala2nd Ave and ...    0.673365
# 181  Travelodge Seattle by The Space Needle200 6th ...    0.629785
# 211  Travelodge Seattle by The Space Needle200 6th ...    0.629785
# 791  citizenM Seattle South Lake Union hotel201 Wes...    0.629524
# 836  citizenM Seattle South Lake Union hotel201 Wes...    0.629524
# 1    Hilton Garden Inn Seattle Downtown1821 Boren A...    0.582417
# 46   Hilton Garden Inn Seattle Downtown1821 Boren A...    0.582417
# 781  Hyatt Regency Lake Washington At SeattleS Sout...    0.580992
# 746  Hyatt Regency Lake Washington At SeattleS Sout...    0.580992
# 551  Quality Inn & Suites Seattle Center618 John St...    0.580919
# 586  Quality Inn & Suites Seattle Center618 John St...    0.580919
# 341  Home2 Suites by Hilton Seattle Airport380 Upla...    0.550270
# 346  Home2 Suites by Hilton Seattle Airport380 Upla...    0.550270
# 616  MarQueen Hotel600 Queen Anne Ave N, Seattle, W...    0.514684
# 406  Mediterranean Inn425 Queen Anne Ave N, Seattle...    0.514684
# 396  Days Inn by Wyndham Seattle North of Downtown9...    0.482200
# 391  Travelodge by Wyndham Seattle North of Downtow...    0.482200
# 636    Hyatt At Olive 81635 8th Ave, Seattle, WA 98101    0.460206
# 631    Hyatt At Olive 91635 8th Ave, Seattle, WA 98101    0.460206
# 561  Renaissance Seattle Hotel515 Madison St, Seatt...    0.458440
# 546  Renaissance Seattle Hotel515 Madison Street, S...    0.458440
# 441  Comfort Inn & Suites13700 Aurora Ave N, Seattl...    0.458070
# 401  Comfort Inn & Suites13700 Aurora Avenue North,...    0.458070
# 671  University Inn - A Staypineapple Hotel4140 Roo...    0.441871
# 706  Watertown Hotel - A Staypineapple Hotel4242 Ro...    0.441871
# 451  Roy Street Commons621 12th Ave E, Seattle, WA ...    0.418808
# 411  Roy Street Commons621 12th Avenue East, Seattl...    0.418808

# %%
matches_df[matches_df['similarity'] < 0.50].right_side.nunique()
# Out:
# 147
